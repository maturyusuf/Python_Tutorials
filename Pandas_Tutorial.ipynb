# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/pandas/survey_results_public.csv") # Reading .csv files

# %%
df.head() # First 5 rows
df.tail() # Last 5 rows
# Out:
#        ResponseId                                         MainBranch  \
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# ...

# %%
df.shape # this attribute gives tuple of (row,column)
# Out:
# (73268, 79)

# %%
df.info() #this method gives detailed info about dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      73268 non-null  int64
#  1   MainBranch                      73268 non-null  object
#  2   Employment                      71709 non-null  object
#  3   RemoteWork                      58958 non-null  object
#  4   CodingActivities                58899 non-null  object
#  5   EdLevel                         71571 non-null  object
#  6   LearnCode                       71580 non-null  object
#  7   LearnCodeOnline                 50685 non-null  object
#  8   LearnCodeCoursesCert            29389 non-null  object
#  9   YearsCode                       71331 non-null  object
#  10  YearsCodePro                    51833 non-null  object
#  11  DevType                         61302 non-null  object
# ...

# %%
pd.set_option("display.max_columns",85) # allows you to display max 85 columns
pd.set_option("display.max_rows",78) # allows you to display max 78 row

# %%
schema_df = pd.read_csv("/content/drive/MyDrive/pandas/survey_results_schema.csv")

# %%
schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2     QID1           S1  <span style="font-size:22px; font-family: aria...
# 3     QID2   MainBranch  Which of the following options best describes ...
# 4   QID296   Employment  Which of the following best describes your cur...
# ..     ...          ...                                                ...
# 74  QID290  Frequency_2  Interacting with people outside of your immedi...
# 75  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp  type selector
# 0       False    DB       TB
# ...

# %%
schema_df.shape
# Out:
# (79, 6)

# %%
df.columns  #it displays all columns as series
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df["MainBranch"] # Displays a certain column(s)
# Out:
# 0                                            None of these
# 1                           I am a developer by profession
# 2        I am not primarily a developer, but I write co...
# 3                           I am a developer by profession
# 4                           I am a developer by profession
#                                ...
# 73263                       I am a developer by profession
# 73264                       I am a developer by profession
# 73265    I am not primarily a developer, but I write co...
# 73266                       I am a developer by profession
# 73267    I used to be a developer by profession, but no...
# Name: MainBranch, Length: 73268, dtype: object

# %%
df["MainBranch"].value_counts() # it classifies responses
# Out:
# I am a developer by profession                                                   53507
# I am learning to code                                                             6309
# I am not primarily a developer, but I write code sometimes as part of my work     5794
# I code primarily as a hobby                                                       4865
# None of these                                                                     1497
# I used to be a developer by profession, but no longer am                          1296
# Name: MainBranch, dtype: int64

# %%
df.loc[0,"MainBranch"] # loc and iloc is being used to find certain data(s).Loc,allows user to pass Column name whilst iloc only allows integer.
# Out:
# 'None of these'

# %%
df.loc[[5,10,15],["MainBranch","YearsCode"]]
# Out:
#                                            MainBranch YearsCode
# 5   I am not primarily a developer, but I write co...        15
# 10                     I am a developer by profession         5
# 15                     I am a developer by profession         4

# %%
df.loc[5:15,["MainBranch","YearsCode"]] 
#While using slicing,we don't surround values with brackets
# Out:
#                                            MainBranch YearsCode
# 5   I am not primarily a developer, but I write co...        15
# 6                         I code primarily as a hobby         3
# 7                      I am a developer by profession         1
# 8                      I am a developer by profession         6
# 9                      I am a developer by profession        37
# 10                     I am a developer by profession         5
# 11  I am not primarily a developer, but I write co...        12
# 12                     I am a developer by profession        12
# 13                     I am a developer by profession        22
# 14                     I am a developer by profession        11
# 15                     I am a developer by profession         4

# %%
df.loc[5:15,"MainBranch":"YearsCode"]
# Out:
#                                            MainBranch  \
# 5   I am not primarily a developer, but I write co...
# 6                         I code primarily as a hobby
# 7                      I am a developer by profession
# 8                      I am a developer by profession
# 9                      I am a developer by profession
# 10                     I am a developer by profession
# 11  I am not primarily a developer, but I write co...
# 12                     I am a developer by profession
# 13                     I am a developer by profession
# 14                     I am a developer by profession
# 15                     I am a developer by profession
#
#                                            Employment  \
# 5                                  Student, full-time
# 6                                  Student, part-time
# 7                  Not employed, but looking for work
# 8                                 Employed, full-time
# ...

# %%
schema_df.set_index("qid",inplace=True) # Set index to a certain column values and save the dataframe by inplace=True argument

# %%
schema_df.head()
# Out:
#              qname                                           question  \
# qid
# QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# QID12     MetaInfo                                  Browser Meta Info
# QID1            S1  <span style="font-size:22px; font-family: aria...
# QID2    MainBranch  Which of the following options best describes ...
# QID296  Employment  Which of the following best describes your cur...
#
#        force_resp  type selector
# qid
# QID16       False    DB       TB
# QID12       False  Meta  Browser
# QID1        False    DB       TB
# QID2         True    MC     SAVR
# QID296      False    MC     MAVR

# %%
schema_df.loc["QID16",["question","force_resp"]] #Now we use loc by passing string to index field
# Out:
# question      <div><span style="font-size:19px;"><strong>Hel...
# force_resp                                                False
# Name: QID16, dtype: object

# %%
schema_df.reset_index(inplace=True) #It resets indexes to back what it was
schema_df.head()
# Out:
#       qid       qname                                           question  \
# 0   QID16          S0  <div><span style="font-size:19px;"><strong>Hel...
# 1   QID12    MetaInfo                                  Browser Meta Info
# 2    QID1          S1  <span style="font-size:22px; font-family: aria...
# 3    QID2  MainBranch  Which of the following options best describes ...
# 4  QID296  Employment  Which of the following best describes your cur...
#
#   force_resp  type selector
# 0      False    DB       TB
# 1      False  Meta  Browser
# 2      False    DB       TB
# 3       True    MC     SAVR
# 4      False    MC     MAVR

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
df = pd.read_csv("/content/drive/MyDrive/pandas/survey_results_public.csv",index_col="ResponseId") # Specifying a column as index
df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                          Fully remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
# 4           Employed, full-time                          Fully remote
# 5           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# ResponseId
# 1                                                NaN
# ...

# %%
schema_df.set_index("qname",inplace=True)

# %%
schema_df
# Out:
#                 qid                                           question  \
# qname
# S0            QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo      QID12                                  Browser Meta Info
# S1             QID1  <span style="font-size:22px; font-family: aria...
# MainBranch     QID2  Which of the following options best describes ...
# Employment   QID296  Which of the following best describes your cur...
# ...             ...                                                ...
# Frequency_2  QID290  Interacting with people outside of your immedi...
# Frequency_3  QID290  Encountering knowledge silos (where one indivi...
# TrueFalse_1  QID294  Are you involved in supporting new hires durin...
# TrueFalse_2  QID294  Do you use learning resources provided by your...
# TrueFalse_3  QID294  Does your employer give you time to learn new ...
#
#             force_resp  type selector
# qname
# S0               False    DB       TB
# ...

# %%
schema_df.loc["MainBranch","question"] # [index,column] or [[indexes],[columns]]
# Out:
# 'Which of the following options best describes you today? Here, by "developer" we mean "someone who writes code." <b>*</b>'

# %%
schema_df.sort_index(inplace=True) # it sorts index alphabetically
schema_df.sort_index(ascending=False,inplace=True) # by setting ascendin=False,it will be sorted reverse alphabetically
schema_df
# Out:
#                          qid  \
# qname
# YearsCodePro           QID34
# YearsCode              QID32
# WorkExp               QID288
# Webframe              QID264
# VersionControlSystem  QID283
# ...                      ...
# CodingActivities      QID297
# BuyNewTool            QID279
# Blockchain            QID305
# Age                   QID127
# Accessibility         QID124
#
#                                                                question  \
# qname
# YearsCodePro          NOT including education, how many years have y...
# YearsCode             Including any education, how many years have y...
# WorkExp               How many years of working experience do you have?
# Webframe              Which <b>web frameworks and web technologies</...
# VersionControlSystem  What are the primary <b>version control system...
# ...                                                                 ...
# CodingActivities      Which of the following best describes the code...
# ...

# %% [markdown]
#  **FILTERING DATA**

# %%
df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                          Fully remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
# 4           Employed, full-time                          Fully remote
# 5           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# ResponseId
# 1                                                NaN
# ...

# %%
filt = (df["Employment"]=="Employed, full-time")
filt
# Out:
# ResponseId
# 1        False
# 2         True
# 3         True
# 4         True
# 5         True
#          ...
# 73264     True
# 73265     True
# 73266     True
# 73267     True
# 73268    False
# Name: Employment, Length: 73268, dtype: bool

# %%
df[filt].head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# 9                              I am a developer by profession
#
#                      Employment                            RemoteWork  \
# ResponseId
# 2           Employed, full-time                          Fully remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
# 4           Employed, full-time                          Fully remote
# 5           Employed, full-time  Hybrid (some remote, some in-person)
# 9           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# ResponseId
# 2           Hobby;Contribute to open-source projects
# ...

# %%
df.loc[filt] #It will get you all the data where employment column's value equals to "Employed, full-time"
# Out:
#                                                    MainBranch  \
# ResponseId
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# 9                              I am a developer by profession
# ...                                                       ...
# 73262                          I am a developer by profession
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
#
#                      Employment                            RemoteWork  \
# ResponseId
# 2           Employed, full-time                          Fully remote
# ...

# %%
df.loc[filt,"MainBranch"]
# Out:
# ResponseId
# 2                           I am a developer by profession
# 3        I am not primarily a developer, but I write co...
# 4                           I am a developer by profession
# 5                           I am a developer by profession
# 9                           I am a developer by profession
#                                ...
# 73262                       I am a developer by profession
# 73264                       I am a developer by profession
# 73265                       I am a developer by profession
# 73266    I am not primarily a developer, but I write co...
# 73267                       I am a developer by profession
# Name: MainBranch, Length: 42962, dtype: object

# %%
df.loc[filt,["MainBranch","EdLevel"]]  #Using .loc to filter our datas and creating new datasets where our filters applied
# Out:
#                                                    MainBranch  \
# ResponseId
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# 9                              I am a developer by profession
# ...                                                       ...
# 73262                          I am a developer by profession
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
#
#                                                     EdLevel
# ResponseId
# 2                                                       NaN
# 3           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
df2=df.dropna(subset=["YearsCode","YearsCodePro"]) # .dropna method delete rows with na values.In this case,it will only delete rows where indicated subset columns are NaN

# %%
filt = ( df["Employment"] == "Employed, full-time") & (df["RemoteWork"]=="Fully remote") #filtering with multiple filters
df.loc[filt]
# Out:
#                                 MainBranch           Employment    RemoteWork  \
# ResponseId
# 2           I am a developer by profession  Employed, full-time  Fully remote
# 4           I am a developer by profession  Employed, full-time  Fully remote
# 18          I am a developer by profession  Employed, full-time  Fully remote
# 23          I am a developer by profession  Employed, full-time  Fully remote
# 32          I am a developer by profession  Employed, full-time  Fully remote
# ...                                    ...                  ...           ...
# 73228       I am a developer by profession  Employed, full-time  Fully remote
# 73234       I am a developer by profession  Employed, full-time  Fully remote
# 73241       I am a developer by profession  Employed, full-time  Fully remote
# 73247       I am a developer by profession  Employed, full-time  Fully remote
# 73264       I am a developer by profession  Employed, full-time  Fully remote
#
# ...

# %%
df.loc[filt,"MainBranch":"CodingActivities"] # Displaying certain filtered values using .loc .first argument is to filter rows,second one is to specify columns to display
# Out:
#                                 MainBranch           Employment    RemoteWork  \
# ResponseId
# 2           I am a developer by profession  Employed, full-time  Fully remote
# 4           I am a developer by profession  Employed, full-time  Fully remote
# 18          I am a developer by profession  Employed, full-time  Fully remote
# 23          I am a developer by profession  Employed, full-time  Fully remote
# 32          I am a developer by profession  Employed, full-time  Fully remote
# ...                                    ...                  ...           ...
# 73228       I am a developer by profession  Employed, full-time  Fully remote
# 73234       I am a developer by profession  Employed, full-time  Fully remote
# 73241       I am a developer by profession  Employed, full-time  Fully remote
# 73247       I am a developer by profession  Employed, full-time  Fully remote
# 73264       I am a developer by profession  Employed, full-time  Fully remote
#
# ...

# %%
filt = ( df["Employment"] == "Employed, full-time") | (df["RemoteWork"]=="Fully remote")
df.loc[ ~filt, "MainBranch":"CodingActivities"]                                           # ~ indicates the opposite state of given contition
#After filtering data,we use .loc to display it
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 6           I am not primarily a developer, but I write co...
# 7                                 I code primarily as a hobby
# 8                              I am a developer by profession
# 20                                      I am learning to code
# ...                                                       ...
# 73253                                   I am learning to code
# 73257                          I am a developer by profession
# 73258                                   I am learning to code
# 73261                          I am a developer by profession
# 73263                                   I am learning to code
#
#                                         Employment  \
# ResponseId
# 1                                              NaN
# 6                               Student, full-time
# ...

# %%
filt= (df['CompTotal'] > 5000.0) & (df["YearsCode"]=="10")
df[filt]
# Out:
#                                                    MainBranch  \
# ResponseId
# 27                             I am a developer by profession
# 74                             I am a developer by profession
# 86                             I am a developer by profession
# 110                            I am a developer by profession
# 159                            I am a developer by profession
# ...                                                       ...
# 73164                          I am a developer by profession
# 73182       I am not primarily a developer, but I write co...
# 73231                          I am a developer by profession
# 73234                          I am a developer by profession
# 73247                          I am a developer by profession
#
#                      Employment                            RemoteWork  \
# ResponseId
# 27          Employed, full-time  Hybrid (some remote, some in-person)
# ...

# %%
df.loc[filt,["MainBranch",	"Employment",	"RemoteWork"]]
# Out:
#                                                    MainBranch  \
# ResponseId
# 27                             I am a developer by profession
# 74                             I am a developer by profession
# 86                             I am a developer by profession
# 110                            I am a developer by profession
# 159                            I am a developer by profession
# ...                                                       ...
# 73164                          I am a developer by profession
# 73182       I am not primarily a developer, but I write co...
# 73231                          I am a developer by profession
# 73234                          I am a developer by profession
# 73247                          I am a developer by profession
#
#                      Employment                            RemoteWork
# ResponseId
# 27          Employed, full-time  Hybrid (some remote, some in-person)
# ...

# %%
countries=["United States","India","United Kingdom","Germany","Canada","Turkey"]

filt = df["Country"].isin(countries)  # .isin() method allows to check if the value contains any elementsS of given list
df.loc[filt,["Country","Currency"]]
# Out:
#             Country              Currency
# ResponseId
# 2            Canada  CAD\tCanadian dollar
# 6           Germany                   NaN
# 7             India                   NaN
# 8             India                   NaN
# 23           Canada  CAD\tCanadian dollar
# ...             ...                   ...
# 73256         India     INR\tIndian rupee
# 73258         India                   NaN
# 73259         India     INR\tIndian rupee
# 73263       Germany                   NaN
# 73268        Canada                   NaN
#
# [15544 rows x 2 columns]

# %%
filt =df["LanguageHaveWorkedWith"].str.contains("Python",na=False) # We are checking if that value contains String of "Python"
df.loc[filt, "LanguageHaveWorkedWith"]
# Out:
# ResponseId
# 3                        C#;C++;HTML/CSS;JavaScript;Python
# 7            C++;HTML/CSS;JavaScript;PHP;Python;TypeScript
# 12       C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL
# 15             HTML/CSS;JavaScript;PHP;Python;R;Ruby;Scala
# 17                                    C#;Java;PHP;Python;R
#                                ...
# 73258                                         C;Python;SQL
# 73262    Bash/Shell;HTML/CSS;Java;JavaScript;Python;SQL...
# 73264    Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73265            Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73266                   HTML/CSS;JavaScript;PHP;Python;SQL
# Name: LanguageHaveWorkedWith, Length: 34155, dtype: object

# %% [markdown]
# **Uptading Rows and Columns**

# %%
df.columns=[x.upper() for x in df.columns]

# %%
df.columns
# Out:
# Index(['MAINBRANCH', 'EMPLOYMENT', 'REMOTEWORK', 'CODINGACTIVITIES', 'EDLEVEL',
#        'LEARNCODE', 'LEARNCODEONLINE', 'LEARNCODECOURSESCERT', 'YEARSCODE',
#        'YEARSCODEPRO', 'DEVTYPE', 'ORGSIZE', 'PURCHASEINFLUENCE', 'BUYNEWTOOL',
#        'COUNTRY', 'CURRENCY', 'COMPTOTAL', 'COMPFREQ',
#        'LANGUAGEHAVEWORKEDWITH', 'LANGUAGEWANTTOWORKWITH',
#        'DATABASEHAVEWORKEDWITH', 'DATABASEWANTTOWORKWITH',
#        'PLATFORMHAVEWORKEDWITH', 'PLATFORMWANTTOWORKWITH',
#        'WEBFRAMEHAVEWORKEDWITH', 'WEBFRAMEWANTTOWORKWITH',
#        'MISCTECHHAVEWORKEDWITH', 'MISCTECHWANTTOWORKWITH',
#        'TOOLSTECHHAVEWORKEDWITH', 'TOOLSTECHWANTTOWORKWITH',
#        'NEWCOLLABTOOLSHAVEWORKEDWITH', 'NEWCOLLABTOOLSWANTTOWORKWITH',
#        'OPSYSPROFESSIONAL USE', 'OPSYSPERSONAL USE', 'VERSIONCONTROLSYSTEM',
#        'VCINTERACTION', 'VCHOSTINGPERSONAL USE', 'VCHOSTINGPROFESSIONAL USE',
#        'OFFICESTACKASYNCHAVEWORKEDWITH', 'OFFICESTACKASYNCWANTTOWORKWITH',
# ...

# %%
columns = df.columns.str.replace("_"," ",) #Using str methods,we can manipulate datas.
columns
# Out:
# Index(['MAINBRANCH', 'EMPLOYMENT', 'REMOTEWORK', 'CODINGACTIVITIES', 'EDLEVEL',
#        'LEARNCODE', 'LEARNCODEONLINE', 'LEARNCODECOURSESCERT', 'YEARSCODE',
#        'YEARSCODEPRO', 'DEVTYPE', 'ORGSIZE', 'PURCHASEINFLUENCE', 'BUYNEWTOOL',
#        'COUNTRY', 'CURRENCY', 'COMPTOTAL', 'COMPFREQ',
#        'LANGUAGEHAVEWORKEDWITH', 'LANGUAGEWANTTOWORKWITH',
#        'DATABASEHAVEWORKEDWITH', 'DATABASEWANTTOWORKWITH',
#        'PLATFORMHAVEWORKEDWITH', 'PLATFORMWANTTOWORKWITH',
#        'WEBFRAMEHAVEWORKEDWITH', 'WEBFRAMEWANTTOWORKWITH',
#        'MISCTECHHAVEWORKEDWITH', 'MISCTECHWANTTOWORKWITH',
#        'TOOLSTECHHAVEWORKEDWITH', 'TOOLSTECHWANTTOWORKWITH',
#        'NEWCOLLABTOOLSHAVEWORKEDWITH', 'NEWCOLLABTOOLSWANTTOWORKWITH',
#        'OPSYSPROFESSIONAL USE', 'OPSYSPERSONAL USE', 'VERSIONCONTROLSYSTEM',
#        'VCINTERACTION', 'VCHOSTINGPERSONAL USE', 'VCHOSTINGPROFESSIONAL USE',
#        'OFFICESTACKASYNCHAVEWORKEDWITH', 'OFFICESTACKASYNCWANTTOWORKWITH',
# ...

# %%
df.rename(columns={'MAINBRANCH':"MainBranch", 'EMPLOYMENT':"Employment", 'REMOTEWORK':"RemoteWork", 'CODINGACTIVITIES':"CodingActivities"},inplace=True)

# %%
df.loc[2,"RemoteWork"] = "FullyRemote"  #we can change specific values 
df.loc[2,"RemoteWork"]
# Out:
# 'FullyRemote'

# %%
df.loc[2,["RemoteWork","Employment"]] = ["FullyRemote","Retired"]

# %%
df.loc[2,["RemoteWork","Employment"]]
# Out:
# RemoteWork    FullyRemote
# Employment        Retired
# Name: 2, dtype: object

# %% [markdown]
# **Changing Multiple Data**

# %%
df["RemoteWork"]=df["RemoteWork"].str.lower()
df["RemoteWork"]
# Out:
# ResponseId
# 1                                         NaN
# 2                                 fullyremote
# 3        hybrid (some remote, some in-person)
# 4                                fully remote
# 5        hybrid (some remote, some in-person)
#                          ...
# 73264                            fully remote
# 73265                          full in-person
# 73266    hybrid (some remote, some in-person)
# 73267    hybrid (some remote, some in-person)
# 73268                            fully remote
# Name: RemoteWork, Length: 73268, dtype: object

# %% [markdown]
# **Multiple Data Change Methods**:
#
#
# *   apply
# *   map
# *   replace
# *   applymap

# %%
#APPLY

# Using "apply" to a series,does the given function to the series
df["MainBranch"].apply(len)
# Out:
# ResponseId
# 1        13
# 2        30
# 3        77
# 4        30
# 5        30
#          ..
# 73264    30
# 73265    30
# 73266    77
# 73267    30
# 73268    56
# Name: MainBranch, Length: 73268, dtype: int64

# %%
def updateLetter(given_value):
  return given_value.upper()

# %%
df["COUNTRY"].fillna("this was na").apply(updateLetter)
# Out:
# ResponseId
# 1                                              THIS WAS NA
# 2                                                   CANADA
# 3        UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...
# 4                                                   ISRAEL
# 5                                 UNITED STATES OF AMERICA
#                                ...
# 73264                                              NIGERIA
# 73265                             UNITED STATES OF AMERICA
# 73266                             UNITED STATES OF AMERICA
# 73267    UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...
# 73268                                               CANADA
# Name: COUNTRY, Length: 73268, dtype: object

# %%
#Instead of using regular functions,we can use Lmbda Functions
df["COUNTRY"].fillna("This was na").apply(lambda x: x.lower())
# Out:
# ResponseId
# 1                                              this was na
# 2                                                   canada
# 3        united kingdom of great britain and northern i...
# 4                                                   israel
# 5                                 united states of america
#                                ...
# 73264                                              nigeria
# 73265                             united states of america
# 73266                             united states of america
# 73267    united kingdom of great britain and northern i...
# 73268                                               canada
# Name: COUNTRY, Length: 73268, dtype: object

# %%
df.apply(len) # if we use apply for our database,it will be applied for columns.
df.apply(len,axis="columns") #If we pass "columns" value to the "axis" argumet,function we passed to the apply method will be executed for rows
# Out:
# ResponseId
# 1        78
# 2        78
# 3        78
# 4        78
# 5        78
#          ..
# 73264    78
# 73265    78
# 73266    78
# 73267    78
# 73268    78
# Length: 73268, dtype: int64

# %%
df["COUNTRY"].fillna("No Country",inplace=True)
df["COUNTRY"].apply(len) #We can use it for particular columns(Series)
# Out:
# ResponseId
# 1        10
# 2         6
# 3        52
# 4         6
# 5        24
#          ..
# 73264     7
# 73265    24
# 73266    24
# 73267    52
# 73268     6
# Name: COUNTRY, Length: 73268, dtype: int64

# %%
df.loc[0:10,["COUNTRY","MainBranch"]].apply(pd.Series.min) # It Sorts given Columns
# Out:
# COUNTRY                               Canada
# MainBranch    I am a developer by profession
# dtype: object

# %%
df.loc[0:10,["COUNTRY","MainBranch"]].apply(lambda x:x.min()) # Lambda version of the sorting function above
# Out:
# COUNTRY                               Canada
# MainBranch    I am a developer by profession
# dtype: object

# %%
df2=df.loc[0:10,["COUNTRY","MainBranch"]]

# %%
df2.applymap(len) #applymap applies function to every element of dataframe
# Out:
#             COUNTRY  MainBranch
# ResponseId
# 1                10          13
# 2                 6          30
# 3                52          77
# 4                 6          30
# 5                24          30
# 6                 7          77
# 7                 5          27
# 8                 5          30
# 9                11          30
# 10                7          30

# %%
df.fillna("Empty String",inplace=True)

# %%
df2=df2.applymap(str.lower)
df2
# Out:
#                                                       COUNTRY  \
# ResponseId
# 1                                                  no country
# 2                                                      canada
# 3           united kingdom of great britain and northern i...
# 4                                                      israel
# 5                                    united states of america
# 6                                                     germany
# 7                                                       india
# 8                                                       india
# 9                                                 netherlands
# 10                                                    croatia
#
#                                                    MainBranch
# ResponseId
# 1                                               none of these
# 2                              i am a developer by profession
# 3           i am not primarily a developer, but i write co...
# ...

# %%
df2["COUNTRY"].map({"no country":"not given"}) # it replaced intended values but also replaced NaN with values that are not indicated.So we use "replace" method to change values
# Out:
# ResponseId
# 1     not given
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# Name: COUNTRY, dtype: object

# %%
df2["COUNTRY"].replace({"no country":"not given"})  # Now it changed given values whilst the ones that are not indicated stay the same before
# Out:
# ResponseId
# 1                                             not given
# 2                                                canada
# 3     united kingdom of great britain and northern i...
# 4                                                israel
# 5                              united states of america
# 6                                               germany
# 7                                                 india
# 8                                                 india
# 9                                           netherlands
# 10                                              croatia
# Name: COUNTRY, dtype: object

# %%
df2.rename(columns={"COUNTRY":"Countries"},inplace = True)

# %%
df2["Countries"]
# Out:
# ResponseId
# 1                                            no country
# 2                                                canada
# 3     united kingdom of great britain and northern i...
# 4                                                israel
# 5                              united states of america
# 6                                               germany
# 7                                                 india
# 8                                                 india
# 9                                           netherlands
# 10                                              croatia
# Name: Countries, dtype: object

# %% [markdown]
# ADDING/REMOVİNG ROWS AND COLUMNS

# %%
people = {
    'first': ['Corey', 'Jane', 'John'], 
    'last': ['Schafer', 'Doe', 'Doe'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']
}

names = pd.DataFrame(people)
names
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
names["full_name"] = names["first"] + " " +  names["last"]   #Adding column
names
# Out:
#    first     last                    email      full_name
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  Corey Schafer
# 1   Jane      Doe        JaneDoe@email.com       Jane Doe
# 2   John      Doe        JohnDoe@email.com       John Doe

# %%
names.drop(columns=["first","last"],inplace=True)   #Removing columns
names
# Out:
#                      email      full_name
# 0  CoreyMSchafer@gmail.com  Corey Schafer
# 1        JaneDoe@email.com       Jane Doe
# 2        JohnDoe@email.com       John Doe

# %%
names["full_name"].str.split(" ")
# Out:
# 0    [Corey, Schafer]
# 1         [Jane, Doe]
# 2         [John, Doe]
# Name: full_name, dtype: object

# %%
names["full_name"].str.split(" ",expand=True) #Using expand will designate all lists into a dataframe
# Out:
#        0        1
# 0  Corey  Schafer
# 1   Jane      Doe
# 2   John      Doe

# %%
names[["first","last"]] = names["full_name"].str.split(" ",expand=True) #We use brackets inside brackets to add multiple column 
names
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe

# %%
 names.append({"first":"Yusuf"},ignore_index=True) #Adding rows to a dataframe
# Out:
# <ipython-input-71-6bbf3923044e>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   names.append({"first":"Yusuf"},ignore_index=True) #Adding rows to a dataframe
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3                      NaN            NaN  Yusuf      NaN

# %%
people={
    "first":["Tony","Steve"],
    "last": ["Stark","Rogers"],
    "email":["TonyStark@avenge.com","Cap@avenge.com"]
}
df2 = pd.DataFrame(people)
df2
# Out:
#    first    last                 email
# 0   Tony   Stark  TonyStark@avenge.com
# 1  Steve  Rogers        Cap@avenge.com

# %%
names.append(df2,ignore_index=True) #How to append a dataframe  to another one
# Out:
# <ipython-input-73-cd3c7a9e76d6>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   names.append(df2,ignore_index=True) #How to append a dataframe  to another one
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3     TonyStark@avenge.com            NaN   Tony    Stark
# 4           Cap@avenge.com            NaN  Steve   Rogers

# %%
names=names.append(df2,ignore_index=True,sort=False) #sort= False argument helps us to manage sorting datas but since append is deprecated,it's wise to use pd.concat instead.
names
# Out:
# <ipython-input-74-ac8567d7de7a>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   names=names.append(df2,ignore_index=True,sort=False) #sort= False argument helps us to manage sorting datas but since append is deprecated,it's wise to use pd.concat instead.
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3     TonyStark@avenge.com            NaN   Tony    Stark
# 4           Cap@avenge.com            NaN  Steve   Rogers

# %%
names.drop(index=4,inplace=False) #Deleting the indexes
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3     TonyStark@avenge.com            NaN   Tony    Stark

# %%
filt=(names["last"]=="Doe")
names.drop(index = names[filt].index,inplace=True) #Removing certain rows with filtering
names
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 3     TonyStark@avenge.com            NaN   Tony    Stark
# 4           Cap@avenge.com            NaN  Steve   Rogers

# %% [markdown]
# **SORTING DATA**

# %%
names.sort_values(by="last",ascending=False) #Sorting by the column 'last' which consisted from string values.So it sorts alphabetically,it was consisted from numbers,it would've been sorted numerically
# Out:
#                      email      full_name  first     last
# 3     TonyStark@avenge.com            NaN   Tony    Stark
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 4           Cap@avenge.com            NaN  Steve   Rogers

# %%
names.sort_values(by=["last","first"],ascending=True)  #if they have identical "last" value, it will sort by the second sorting parameter which is "first"
# Out:
#                      email      full_name  first     last
# 4           Cap@avenge.com            NaN  Steve   Rogers
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 3     TonyStark@avenge.com            NaN   Tony    Stark

# %%
names.sort_values(by=["last","first"],ascending=[False,True]) # in last ascending order is false,in first ascending order is true
# Out:
#                      email      full_name  first     last
# 3     TonyStark@avenge.com            NaN   Tony    Stark
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 4           Cap@avenge.com            NaN  Steve   Rogers

# %%
names.sort_index() #sorting index
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 3     TonyStark@avenge.com            NaN   Tony    Stark
# 4           Cap@avenge.com            NaN  Steve   Rogers

# %%
names["last"].sort_values() #sorting a single column
# Out:
# 4     Rogers
# 0    Schafer
# 3      Stark
# Name: last, dtype: object

# %%
df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                  Empty String                          Empty String
# 2                       Retired                           fullyremote
# 3           Employed, full-time  hybrid (some remote, some in-person)
# 4           Employed, full-time                          fully remote
# 5           Employed, full-time  hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# ResponseId
# 1                                       Empty String
# ...

# %%
df.sort_values(by="COUNTRY",inplace=True)

# %%
df["COUNTRY"]
# Out:
# ResponseId
# 69587    Afghanistan
# 56189    Afghanistan
# 71716    Afghanistan
# 33329    Afghanistan
# 67667    Afghanistan
#             ...
# 4719        Zimbabwe
# 57743       Zimbabwe
# 25819       Zimbabwe
# 71358       Zimbabwe
# 30391       Zimbabwe
# Name: COUNTRY, Length: 73268, dtype: object

# %%
df[["COUNTRY","CONVERTEDCOMPYEARLY"]].head(50)
# Out:
#                 COUNTRY CONVERTEDCOMPYEARLY
# ResponseId
# 69587       Afghanistan        Empty String
# 56189       Afghanistan        Empty String
# 71716       Afghanistan        Empty String
# 33329       Afghanistan        Empty String
# 67667       Afghanistan        Empty String
# 28435       Afghanistan        Empty String
# 21766       Afghanistan        Empty String
# 33429       Afghanistan        Empty String
# 61936       Afghanistan        Empty String
# 60517       Afghanistan        Empty String
# 3776        Afghanistan        Empty String
# 42123       Afghanistan        Empty String
# 43691       Afghanistan             13212.0
# 6243        Afghanistan              5280.0
# 30851       Afghanistan        Empty String
# 53961       Afghanistan        Empty String
# 56267       Afghanistan        Empty String
# 23162       Afghanistan        Empty String
# 10911       Afghanistan        Empty String
# 2449        Afghanistan             10894.0
# ...

# %%
df.sort_values(by=["COUNTRY","CONVERTEDCOMPYEARLY"],ascending=[False,True],inplace=True)

# %%
df[["CONVERTEDCOMPYEARLY","COUNTRY"]].head(10)
# Out:
#            CONVERTEDCOMPYEARLY   COUNTRY
# ResponseId
# 44536                   3600.0  Zimbabwe
# 31003                   7200.0  Zimbabwe
# 66478                  10000.0  Zimbabwe
# 71980                  10800.0  Zimbabwe
# 30291                  12000.0  Zimbabwe
# 64032                  13200.0  Zimbabwe
# 59418                  75000.0  Zimbabwe
# 36078                 568968.0  Zimbabwe
# 46673             Empty String  Zimbabwe
# 52824             Empty String  Zimbabwe

# %%
df["CONVERTEDCOMPYEARLY"].replace("Empty String",0,inplace=True)
df["CONVERTEDCOMPYEARLY"] = df["CONVERTEDCOMPYEARLY"].astype(float) #Chnaging the type of dataframe or column

# %%
df["CONVERTEDCOMPYEARLY"].nlargest(10) #Fetches the largest 10 value
# Out:
# ResponseId
# 40305    50000000.0
# 202      44790396.0
# 62027    35000000.0
# 70523    32500000.0
# 61044    28853768.0
# 18923    22500000.0
# 62224    22500000.0
# 66496    18000000.0
# 1291     15000000.0
# 24164    15000000.0
# Name: CONVERTEDCOMPYEARLY, dtype: float64

# %%
df["CONVERTEDCOMPYEARLY"].nsmallest(10) #Fetches the smallest 10 value
# Out:
# ResponseId
# 46673    0.0
# 52824    0.0
# 19594    0.0
# 24120    0.0
# 68960    0.0
# 38746    0.0
# 43528    0.0
# 72145    0.0
# 44771    0.0
# 25845    0.0
# Name: CONVERTEDCOMPYEARLY, dtype: float64

# %% [markdown]
# GROUPING & AGGREGATING

# %%
df.head()
# Out:
#                                 MainBranch  \
# ResponseId
# 44536       I am a developer by profession
# 31003       I am a developer by profession
# 66478       I am a developer by profession
# 71980       I am a developer by profession
# 30291       I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 44536                                     Employed, full-time
# 31003                                     Employed, full-time
# 66478       Independent contractor, freelancer, or self-em...
# 71980                                     Employed, full-time
# 30291                                     Employed, full-time
#
#                                       RemoteWork  \
# ResponseId
# 44536                             full in-person
# 31003       hybrid (some remote, some in-person)
# 66478                               fully remote
# 71980       hybrid (some remote, some in-person)
# ...

# %%
# Aggregation = med,median, vs .. grouping datas based on a common mathematical filter
df["CONVERTEDCOMPYEARLY"].head()
# Out:
# ResponseId
# 44536     3600.0
# 31003     7200.0
# 66478    10000.0
# 71980    10800.0
# 30291    12000.0
# Name: CONVERTEDCOMPYEARLY, dtype: float64

# %%
df["CONVERTEDCOMPYEARLY"].median  # it grabs only numerical values and does the math via those and ignores other values
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of ResponseId
# 44536     3600.0
# 31003     7200.0
# 66478    10000.0
# 71980    10800.0
# 30291    12000.0
#           ...
# 51189        0.0
# 46026        0.0
# 61618        0.0
# 69400        0.0
# 17470        0.0
# Name: CONVERTEDCOMPYEARLY, Length: 73268, dtype: float64>

# %%
df.median()  #it grabs only numerical values and does the math via those and ignores other values
# Out:
# <ipython-input-94-b93f1d09423d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()  #it grabs only numerical values and does the math via those and ignores other values
# CONVERTEDCOMPYEARLY    5736.0
# dtype: float64

# %%
df.describe() # Give mathematical description
# -count:Number  of nan value rows
#-mean:mean
#std:Standard deviation
# Out:
#        CONVERTEDCOMPYEARLY
# count         7.326800e+04
# mean          8.872977e+04
# std           5.696963e+05
# min           0.000000e+00
# 25%           0.000000e+00
# 50%           5.736000e+03
# 75%           7.027600e+04
# max           5.000000e+07

# %%
df["SURVEYLENGTH"].value_counts() #Counts and groups by values
# Out:
# Appropriate in length    53883
# Too long                 14491
# Empty String              2824
# Too short                 2070
# Name: SURVEYLENGTH, dtype: int64

# %%
df["SURVEYLENGTH"].value_counts(normalize=True) #Counts and groups by values as percentages
# Out:
# Appropriate in length    0.735423
# Too long                 0.197781
# Empty String             0.038543
# Too short                0.028252
# Name: SURVEYLENGTH, dtype: float64

# %% [markdown]
# Group by Function: it involves combination of SPLITING THE OBJECT, APPLYING THE FUNCTION AND COMBINING THE RESULTS

# %%
df["COUNTRY"].value_counts()
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# San Marino                                                  1
# Solomon Islands                                             1
# Saint Kitts and Nevis                                       1
# Seychelles                                                  1
# Monaco                                                      1
# Name: COUNTRY, Length: 181, dtype: int64

# %%
#1-SPLITTING THE  OBJECT
country_group = df.groupby(["COUNTRY"])

# %%
country_group.get_group("United States of America") #We get all the df where COUNTRY value is USA
# Out:
#                                                    MainBranch  \
# ResponseId
# 64367       I am not primarily a developer, but I write co...
# 37090                          I am a developer by profession
# 19665                          I am a developer by profession
# 63664                          I am a developer by profession
# 27333                          I am a developer by profession
# ...                                                       ...
# 40212       I am not primarily a developer, but I write co...
# 40211                                   I am learning to code
# 58630                                   I am learning to code
# 12087       I am not primarily a developer, but I write co...
# 13135                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 64367                                     Employed, full-time
# 37090                                     Employed, part-time
# ...

# %%
filt=(df["COUNTRY"]=="United States of America")  #It's the same as groupby method
df.loc[filt]
# Out:
#                                                    MainBranch  \
# ResponseId
# 64367       I am not primarily a developer, but I write co...
# 37090                          I am a developer by profession
# 19665                          I am a developer by profession
# 63664                          I am a developer by profession
# 27333                          I am a developer by profession
# ...                                                       ...
# 40212       I am not primarily a developer, but I write co...
# 40211                                   I am learning to code
# 58630                                   I am learning to code
# 12087       I am not primarily a developer, but I write co...
# 13135                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 64367                                     Employed, full-time
# 37090                                     Employed, part-time
# ...

# %%
#2-APPLY FUNCTION
filt=(df["COUNTRY"]=="India")  #It's the same as groupby method
df.loc[filt]["EDLEVEL"].value_counts()
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          4121
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       1129
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     704
# Some college/university study without earning a degree                                 334
# Primary/elementary school                                                              158
# Something else                                                                          80
# Professional degree (JD, MD, etc.)                                                      46
# Empty String                                                                            23
# Other doctoral degree (Ph.D., Ed.D., etc.)                                              23
# Associate degree (A.A., A.S., etc.)                                                     21
# Name: EDLEVEL, dtype: int64

# %%
country_group["ORGSIZE"].value_counts().head(10)
# Out:
# COUNTRY      ORGSIZE
# Afghanistan  Empty String                                          35
#              2 to 9 employees                                       6
#              100 to 499 employees                                   5
#              10 to 19 employees                                     4
#              500 to 999 employees                                   4
#              Just me - I am a freelancer, sole proprietor, etc.     4
#              I don’t know                                           3
#              1,000 to 4,999 employees                               2
#              10,000 or more employees                               2
#              20 to 99 employees                                     2
# Name: ORGSIZE, dtype: int64

# %%
country_group["ORGSIZE"].value_counts().loc["China"] #We can filter it by using loc and passing the index
# Out:
# ORGSIZE
# Empty String                                          311
# 10,000 or more employees                               64
# 20 to 99 employees                                     61
# 100 to 499 employees                                   51
# 1,000 to 4,999 employees                               45
# 2 to 9 employees                                       27
# 10 to 19 employees                                     21
# 5,000 to 9,999 employees                               17
# 500 to 999 employees                                   14
# Just me - I am a freelancer, sole proprietor, etc.     13
# I don’t know                                            8
# Name: ORGSIZE, dtype: int64

# %%
country_group["CONVERTEDCOMPYEARLY"].median().loc["Germany"]
# Out:
# 38388.0

# %%
country_group["CONVERTEDCOMPYEARLY"].agg(["mean","median"])
# Out:
# mean      136051.116867
# median     62463.500000
# Name: Canada, dtype: float64

# %%
country_group["CONVERTEDCOMPYEARLY"].agg(["mean","median"]).loc["Canada"]
# Out:
# mean      136051.116867
# median     62463.500000
# Name: Canada, dtype: float64

# %%
filt=(df["COUNTRY"]=="India")  #It's the same as groupby method
df.loc[filt]["LEARNCODECOURSESCERT"].str.contains("Udemy")
# Out:
# ResponseId
# 39916     True
# 65743     True
# 58971     True
# 4239      True
# 36976     True
#          ...
# 42378     True
# 20954    False
# 16552    False
# 16570    False
# 52819     True
# Name: LEARNCODECOURSESCERT, Length: 6639, dtype: bool

# %%
df.loc[filt]["CodingActivities"].str.contains("Hobby").sum()
# Out:
# 3128

# %%
osize_group =df.groupby("ORGSIZE")
osize_group["CodingActivities"].apply(lambda x: x.str.contains("Hobby").sum()) 
# We grouped dataframe by the values of the column called "ORGSIZE" and checked how much the 
# "Hobby" value each group has using apply method,which allows user to apply methods to series
# Out:
# ORGSIZE
# 1,000 to 4,999 employees                              4166
# 10 to 19 employees                                    3029
# 10,000 or more employees                              5139
# 100 to 499 employees                                  6761
# 2 to 9 employees                                      3352
# 20 to 99 employees                                    7524
# 5,000 to 9,999 employees                              1650
# 500 to 999 employees                                  2596
# Empty String                                          6363
# I don’t know                                           684
# Just me - I am a freelancer, sole proprietor, etc.    1658
# Name: CodingActivities, dtype: int64

# %%
c_group = df.groupby("COUNTRY")
c_group["LANGUAGEHAVEWORKEDWITH"].apply(lambda x:x.str.contains("Python").sum())

# %% [markdown]
# **CEANING DATA & CASTING DATATYPES**

# %%
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}
df = pd.DataFrame(people)

# %%
df.dropna() #Deletes all the rows contains NaN
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
df.dropna(axis="index",how="any") # deletes any indexes with NaN   axis="columns": drops columns
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
df.dropna(axis="columns",how="any") # deletes columns contain NaN
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %%
df.dropna(axis="index",how="any",subset=["email"]) #in subset,it only looks for given columns,in that case "email" column for default NaN values.We'll treat custom non values different
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 5   None      NaN      Anonymous@email.com  None

# %%
df.dropna(axis="index",how="all",subset=["last","email"]) #drop all the default NaN values that dont have "last" and "email".
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 5   None      NaN      Anonymous@email.com  None

# %%
df.replace("NA",np.nan,inplace=True) #changing Custom na values to default na

# %%
df.replace("None",np.nan,inplace=True) #changing Custom na values to default na
df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df.fillna("Missing") #filling na values
# Out:
#      first     last                    email      age
# 0    Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1     Jane      Doe        JaneDoe@email.com       55
# 2     John      Doe        JohnDoe@email.com       63
# 3    Chris  Schafer                  Missing       36
# 4  Missing  Missing                  Missing  Missing
# 5  Missing  Missing      Anonymous@email.com  Missing
# 6  Missing  Missing                  Missing  Missing

# %%
df.dtypes #shows columns' type
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
df["age"].astype(int) # it won't covert because na values can't be converted.So there will be an error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-157-a4b00feb0681> in <cell line: 1>()
# ----> 1 df["age"].astype(int)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# ...

# %%
df["age"]=df["age"].fillna(0).astype(float) #Changing the type

# %%
df.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
filt=(df["age"] == 0)  # Assigning mean value to 0s
df.loc[filt,"age"] = df["age"].mean()

# %%
df
# Out:
#    first     last                    email        age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33.000000
# 1   Jane      Doe        JaneDoe@email.com  55.000000
# 2   John      Doe        JohnDoe@email.com  63.000000
# 3  Chris  Schafer                     None  36.000000
# 4    NaN      NaN                      NaN  26.714286
# 5   None      NaN      Anonymous@email.com  26.714286
# 6    NaN      NaN                      NaN  26.714286

# %%
df = pd.read_csv("/content/drive/MyDrive/pandas/survey_results_public.csv",na_values=["NA","Missing"]) # Turning custom na values to default ones with read_csv

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
df["YearsCode"].unique()
# Out:
# array([nan, '14', '20', '8', '15', '3', '1', '6', '37', '5', '12', '22',
#        '11', '4', '7', '13', '36', '2', '25', '10', '40', '16', '27',
#        '24', '19', '9', '17', '18', '26', 'More than 50 years', '29',
#        '30', '32', 'Less than 1 year', '48', '45', '38', '39', '28', '23',
#        '43', '21', '41', '35', '50', '33', '31', '34', '46', '44', '42',
#        '47', '49'], dtype=object)

# %%
df["YearsCode"].replace('More than 50 years',0,inplace=True)
df["YearsCode"].replace('Less than 1 year',0,inplace=True)
df["YearsCode"]
# Out:
# 0        NaN
# 1        NaN
# 2         14
# 3         20
# 4          8
#         ...
# 73263      8
# 73264      6
# 73265     42
# 73266     50
# 73267     16
# Name: YearsCode, Length: 73268, dtype: object

# %%
df["YearsCode"].unique()
# Out:
# array([nan, '14', '20', '8', '15', '3', '1', '6', '37', '5', '12', '22',
#        '11', '4', '7', '13', '36', '2', '25', '10', '40', '16', '27',
#        '24', '19', '9', '17', '18', '26', 0, '29', '30', '32', '48', '45',
#        '38', '39', '28', '23', '43', '21', '41', '35', '50', '33', '31',
#        '34', '46', '44', '42', '47', '49'], dtype=object)

# %%
df["YearsCode"] = df["YearsCode"].astype(float)

# %%
mean_age=df["YearsCode"].mean()

# %%
df["YearsCode"].replace(0,mean_age,inplace=True)

# %%
df["YearsCode"].unique()
# Out:
# array([       nan, 14.       , 20.       ,  8.       , 15.       ,
#         3.       ,  1.       ,  6.       , 37.       ,  5.       ,
#        12.       , 22.       , 11.       ,  4.       ,  7.       ,
#        13.       , 36.       ,  2.       , 25.       , 10.       ,
#        40.       , 16.       , 27.       , 24.       , 19.       ,
#         9.       , 17.       , 18.       , 26.       , 12.1283313,
#        29.       , 30.       , 32.       , 48.       , 45.       ,
#        38.       , 39.       , 28.       , 23.       , 43.       ,
#        21.       , 41.       , 35.       , 50.       , 33.       ,
#        31.       , 34.       , 46.       , 44.       , 42.       ,
#        47.       , 49.       ])

# %% [markdown]
# **DATETIME & TIME SERIES**

# %%
df=pd.read_csv("/content/drive/MyDrive/pandas/ETH_1h.csv")
df.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
df.loc[0, "Date"].day_name() #Since "Date" column consist from str values, we can't use a datetime method on it
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-204-daac2243067c> in <cell line: 1>()
# ----> 1 df.loc[0, "Date"].day_name()
#
# AttributeError: 'str' object has no attribute 'day_name'

# %%
df["Date"] = pd.to_datetime(df["Date"],format="%Y-%m-%d %I-%p") #We turned into "DayTime" type

# %%
df["Date"]
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
df.loc[0,"Date"].day_name()
# Out:
# 'Friday'

# %%
# We can change strings to daytrime whilst specifying dataframe

d_parser= lambda x:pd.datetime.strptime(x,"%Y-%m-%d %I-%p")
df = pd.read_csv("/content/drive/MyDrive/pandas/ETH_1h.csv",parse_dates=["Date"],date_parser=d_parser)
df
# Out:
# <ipython-input-212-cdbff1a4431e>:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   d_parser= lambda x:pd.datetime.strptime(x,"%Y-%m-%d %I-%p")
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# ...

# %%
df["Date"].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df["DayOfWeek"] = df["Date"].dt.day_name() #Accesing date_time class using "dt"
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       DayOfWeek
# ...

# %%
df["Date"].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df["Date"].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df["Date"].max() - df["Date"].min() # Range of Days
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt = (df["Date"] >= "2020") #pandas will know this string is for datetime
df.loc[filt]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 1748 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#       DayOfWeek
# 0        Friday
# ...

# %%
filt = (df["Date"] >= "2019" ) & (df["Date"] < "2020" ) 
df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
filt = (df["Date"] >= pd.to_datetime("2019-01-01") ) & (df["Date"] < pd.to_datetime("2020-01-01") ) 
df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
df.set_index("Date",inplace=True)

# %%
df
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
df["2019"]
# Out:
# <ipython-input-227-01f1be04b9d5>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df["2019"]
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# ...

# %%
df["2020-01":"2020-02"]
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                      DayOfWeek
# Date
# 2020-02-29 23:00:00   Saturday
# ...

# %%
df["2020-01":"2020-02"]["Close"].mean()
# Out:
# 195.1655902777778

# %%
df["2020-01":"2020-02"].head(24)
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# 2020-02-29 18:00:00  ETHUSD  225.53  226.17  224.50  225.09   496543.91
# 2020-02-29 17:00:00  ETHUSD  222.68  225.53  222.24  225.53   611136.47
# 2020-02-29 16:00:00  ETHUSD  224.17  225.93  222.36  222.68   694384.75
# 2020-02-29 15:00:00  ETHUSD  223.35  225.88  221.80  224.17   550893.74
# 2020-02-29 14:00:00  ETHUSD  224.42  224.42  221.15  223.35  1479928.44
# 2020-02-29 13:00:00  ETHUSD  225.29  225.37  222.87  224.42  1076646.41
# 2020-02-29 12:00:00  ETHUSD  226.50  226.50  224.14  225.29   359022.09
# ...

# %%
df["2020-01-01"]["High"].max()
# Out:
# <ipython-input-232-5f9726cdfd06>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df["2020-01-01"]["High"].max()
# 132.68

# %% [markdown]
# Resampling

# %%
highs=df["High"].resample("D").max() # it gives each values of "High" on daily basis because of resampling by "D"
 #"D","W"...Check resampling types from the documentation

# %%
highs["2020-01-01"]
# Out:
# 132.68

# %%
df.resample("W").mean() #Resample all dataframe
# Out:
# <ipython-input-237-5f54b50f91fd>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.resample("W").mean() #Resample all dataframe
#                   Open        High         Low       Close        Volume
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06
# 2017-07-30  203.496190  205.110357  201.714048  203.309524  1.581729e+06
# ...                ...         ...         ...         ...           ...
# 2020-02-16  255.021667  257.255238  252.679762  255.198452  2.329087e+06
# ...

# %%
df.resample("W").agg({"Close":"mean","High":"max","Low":"min","Volume":"sum"})
# Out:
#                  Close    High     Low        Volume
# Date
# 2017-07-02  268.202162  293.73  253.23  8.084631e+07
# 2017-07-09  261.062083  285.00  231.25  2.246746e+08
# 2017-07-16  195.698393  240.33  130.26  5.017750e+08
# 2017-07-23  212.783750  249.40  153.25  7.221637e+08
# 2017-07-30  203.309524  229.99  178.03  2.657305e+08
# ...                ...     ...     ...           ...
# 2020-02-16  255.198452  290.00  216.31  3.912867e+08
# 2020-02-23  265.321905  287.13  242.36  3.067838e+08
# 2020-03-01  236.373988  278.13  209.26  3.693920e+08
# 2020-03-08  229.817619  253.01  196.00  2.736569e+08
# 2020-03-15  176.332821  208.65   90.00  4.983998e+08
#
# [142 rows x 4 columns]

# %% [markdown]
# **READ & WRITE DATA**

# %%
new_df=df.resample("W").agg({"Close":"mean","High":"max","Low":"min","Volume":"sum"})

# %%
new_df.to_csv("/content/drive/MyDrive/pandas/new_df.csv") #Write .csv
